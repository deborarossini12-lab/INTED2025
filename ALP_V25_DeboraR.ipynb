# %% [markdown]
# <a href="https://colab.research.google.com/github/deborarossini12-lab/INTED2025/blob/main/ALP_V25_DeboraR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Algoritmo e Lógica de Programação

# %% [markdown]
# ##Variáveis

# %%
a = 5 #Isso é uma variável que recebe o valor 5
b = 10
print(a+b)
# Out:
# 15

# %%
a = int(input("Digite um número: "))
b = int(input("Digite um número: "))
print(a+b)
# Out:
# Digite um número: 13
# Digite um número: 22
# 35

# %% [markdown]
# ##Tipos de Dados
#
# int - inteiro - para números inteiros
#
# float - flutuante - para números com vírgula
#
# str - string (caracteres) - para palavras
#
# bool - booleano (binário) - para verdadeiro e falso

# %%
x = int(input("Digite um número: "))
y = float(input("Digite um número com vírgula: "))
z = str(input("Digite uma palavra: "))
w = bool(input("Digite um valor booleano: "))
# Out:
# Digite um número: 1
# Digite um número com vírgula: 2
# Digite uma palavra: PT
# Digite um valor booleano: True

# %%
print(x)
print(y)
print(z)
print(w)
# Out:
# 1
# 2.0
# PT
# True

# %%
i = a + b
k = a - b
j = a * b
m = a / b

print(i)
print(k)
print(j)
print(m)
# Out:
# 35
# -9
# 286
# 0.5909090909090909

# %%
numero1 = int(input("Digite um número:"))
numero2 = int(input("Digite outro número:"))

expo = numero1 ** numero2

print(numero1 , " elevado à ", numero2 , "é igual a: ", expo)
# Out:
# Digite um número:1
# Digite outro número:3
# 1  elevado à  3 é igual a:  1

# %% [markdown]
# 1- Crie um algoritmo que receba na variável nome o nome do usuário, e na idade do usuário. E depois imprima na tela a seguinte frase:
#
# Olá, meu nome é (nome) e eu tenho (idade) anos!

# %%
nome = str(input("Digite um nome: "))
idade = int(input("Digite uma idade: "))

print("Olá, meu nome é" , nome , "e eu tenho" , idade , "anos!")
# Out:
# Digite um nome: Karla
# Digite uma idade: 21
# Olá, meu nome é Karla e eu tenho 21 anos!

# %%
#Calculadora de IMC
peso = float(input("Digite seu peso: "))
altura = float(input("Digite sua altura: "))

print("Seu IMC é: ", peso / (altura * altura))
# Out:
# Digite seu peso: 69.90
# Digite sua altura: 1.68
# Seu IMC é:  24.76615646258504

# %% [markdown]
# ##Estrutura condicional
#
# if - se
#
# elif - senão se
#
# else - senão

# %%
nota = float(input("Digite sua nota: "))

if nota >= 7:
  print("Aprovado")
elif nota >= 5:
  print("Recuperação")
else:
  print("Reprovado")
# Out:
# Digite sua nota: 5
# Recuperação

# %% [markdown]
# 4- Crie um algoritmo que receba uma idade do usuário, e depois verifique em qual faixa etária está a idade:
#
# até 12 - Você é uma criança!
#
# de 13 á 18 - Você é um Adolescente!
#
# de 19 á 60 -  Você é um adulto!
#
# acima de 60 - Você é idoso!

# %%
idade = int(input("Digite sua idade: "))

if idade <= 12:
  print("Você é uma criança!")
elif idade >= 13 and idade <= 18:
  print("Você é um Adolescente!")
elif idade >= 19 and idade <= 60:
  print("Você é um adulto!")
else:
  print("Você é idoso!")
# Out:
# Digite sua idade: 16
# Você é um Adolescente!
